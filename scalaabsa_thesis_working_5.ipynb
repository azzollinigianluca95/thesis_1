# %% [markdown]
# <a href="https://colab.research.google.com/github/azzollinigianluca95/thesis_1/blob/main/scalaabsa_thesis_working_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -u "/content/drive/MyDrive/file.zip" -d "/"
# Out:
# Archive:  /content/drive/MyDrive/file.zip
#    creating: /content/Aspect-Based-Sentiment-Analysis/
#    creating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/
#   inflating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/models.py
#   inflating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/data_types.py
#   inflating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/__init__.py
#   inflating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/alignment.py
#   inflating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/text_splitters.py
#    creating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/__pycache__/
#   inflating: /content/Aspect-Based-Sentiment-Analysis/aspect_based_sentiment_analysis/__pycache__/pipelines.cpython-36.pyc
# ...

# %%
#CREATE ZIP OF A FOLDER:
# !zip -r /content/file.zip /content/Aspect-Based-Sentiment-Analysis
#MOVE TO DRIVE
# !cp /content/file.zip /content/drive/MyDrive

# %%
#TO START FROM THE BEGINNING POINT
#!git clone https://github.com/ScalaConsultants/Aspect-Based-Sentiment-Analysis.git
# Out:
# Cloning into 'Aspect-Based-Sentiment-Analysis'...
# remote: Enumerating objects: 357, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 1238 (delta 216), reused 310 (delta 198), pack-reused 881
# Receiving objects: 100% (1238/1238), 1.89 MiB | 28.95 MiB/s, done.
# Resolving deltas: 100% (755/755), done.

# %%
#A)
#ARTICLE: https://towardsdatascience.com/conda-google-colab-75f7c867a522
# !python --version
#B)
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# !chmod +x Miniconda3-4.5.4-Linux-x86_64.sh
# !bash ./Miniconda3-4.5.4-Linux-x86_64.sh -b -f -p /usr/local
# update 1
# !conda install -q -y --prefix /usr/local python=3.6 ujson
# update 2
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages')
# test it
import ujson
print(ujson.dumps({1:2}))
#C)
# !which conda
#D)
# !conda --version
# !which python
# !python --version
# !conda install --channel defaults conda python=3.6 --yes
# !conda update --channel defaults --all --yes
#E)
# !conda --version # now returns 4.8.3
# !python --version # now returns Python 3.6.10 :: Anaconda, Inc.
#F)
import sys
sys.path
#F)
'''Now all you need to do is install you favorite packages. Just remember 
to include the --yes flag when installing your packages to avoid getting 
prompted to confirm the package plan.'''
# !conda install --channel conda-forge featuretools --yes
# Out:
# Python 3.6.9
# --2020-12-27 21:08:44--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M   202MB/s    in 0.3s
#
# 2020-12-27 21:08:44 (202 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# ...

# %%
# !conda env create -f=/content/Aspect-Based-Sentiment-Analysis/environment.yml #--force
# Out:
# ...
# done
# -
# ...
#   - defaults/linux-64::jedi-0.17.0-py36_0, defaults/noarch::parso-0.8.1-pyhd3eb1b0_0
# done
#
# ...
# scikit-learn-0.22.1  | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# done
# done
# done
# \ Ran pip subprocess with arguments:
# ['/usr/local/envs/Aspect-Based-Sentiment-Analysis/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/Aspect-Based-Sentiment-Analysis/condaenv.vahcetpu.requirements.txt']
# Pip subprocess output:
# ...
#   Created wheel for optuna: filename=optuna-1.3.0-py3-none-any.whl size=221120 sha256=746be121c73c6b755955ce9491b3dbada13040b9258aadffb0e5340e184dc42d
#   Stored in directory: /root/.cache/pip/wheels/89/f9/1c/649ef739b35d9fc6ba0752053b997e3aa1bc30e5662f295f18
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=cb6a42424cdae296a4e1376815e94c9558ab6ee8be4712b0fb5706188ef8571b
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
# ...

# %%
# %%bash
# source activate Aspect-Based-Sentiment-Analysis
# python
# import sys
# # maybe only need this the first time we run this notebook
# sys.path.append('/usr/local/lib/python3.6/site-packages')
#
# print("Python version")
# print(sys.version)
# Out:
# Python version
# 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0]

# %%
# %%writefile /content/Aspect-Based-Sentiment-Analysis/prova.py
from aspect_based_sentiment_analysis import aux_models
from aspect_based_sentiment_analysis import utils
from aspect_based_sentiment_analysis import loads
from aspect_based_sentiment_analysis import plots

text = ("the new boss was crazy: he went around the rooms in a crazy way. Employees were aware of that, and they always smile when they used to talk with him. Managers are good people always drink a coffee whit the boss seeming and agree with him, even if they didn't want. This is a perfect day: the boss is ok")
recognizer = aux_models.BasicPatternRecognizer()
nlp = loads.load(pattern_recognizer=recognizer)
completed_task = nlp(text=text, aspects=['boss', 'manager'])
subscriptions, price = completed_task.examples

plots.summary(price)
plots.display(price.review)
plots.summary(subscriptions)
plots.display(subscriptions.review)
# Out:
# Overwriting /content/Aspect-Based-Sentiment-Analysis/prova.py

# %%
# !conda install tensorflow-gpu
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tensorflow-gpu
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.1.0        |              gpu           2 KB
#     absl-py-0.11.0             |     pyhd3eb1b0_1         103 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     blinker-1.4                |           py36_0          22 KB
#     c-ares-1.17.1              |       h27cfd23_0         108 KB
#     cachetools-4.2.0           |     pyhd3eb1b0_0          13 KB
#     cudatoolkit-10.1.243       |       h6bb024c_0       347.4 MB
#     cudnn-7.6.5                |       cuda10.1_0       179.9 MB
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 9.5 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 33.3 MB/s
# ...
#   Using cached regex-2020.11.13-cp36-cp36m-manylinux2014_x86_64.whl (723 kB)
# ...
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# ...
#   Using cached sacremoses-0.0.43-py3-none-any.whl
# ...
#      |████████████████████████████████| 302 kB 70.8 MB/s
# ...

# %%
# !pip install google-cloud-bigquery
# Out:
# ...
#      |████████████████████████████████| 211 kB 9.4 MB/s
# ...
#   Using cached google_api_core-1.24.1-py2.py3-none-any.whl (92 kB)
# ...
#   Using cached google_cloud_core-1.5.0-py2.py3-none-any.whl (27 kB)
# ...
#      |████████████████████████████████| 75 kB 4.3 MB/s
# ...
#   Using cached googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
# ...
#      |████████████████████████████████| 44 kB 2.7 MB/s
# ...
#   Created wheel for proto-plus: filename=proto_plus-1.13.0-py3-none-any.whl size=41592 sha256=4ac927873005fe957f089640bf03b2400a263367cc330cd523136ee8c6c26f8b
#   Stored in directory: /root/.cache/pip/wheels/5a/76/e1/dd2dc8192e9a6b687d8c7550acc7c8edf059a4f16296e7ea89
# Successfully built proto-plus
# ...

# %%
# !pip install aspect-based-sentiment-analysis
# Out:
# ...
#   Using cached scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
# ...
#   Using cached transformers-2.5.0-py3-none-any.whl (481 kB)
# ...
#   Using cached tokenizers-0.5.0-cp36-cp36m-manylinux1_x86_64.whl (3.8 MB)
# ...
#   Using cached tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
# ...
#   Using cached boto3-1.16.43-py2.py3-none-any.whl (130 kB)
# ...
#   Using cached botocore-1.19.43-py2.py3-none-any.whl (7.2 MB)
# ...
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# ...
#   Using cached s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# ...
#      |████████████████████████████████| 96 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 785 kB 19.1 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 37.7 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 355 kB 61.1 MB/s
# ...
#      |████████████████████████████████| 75 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 258 kB 56.9 MB/s
#   Installing build dependencies ... done
# ...

# %%
# !python /content/Aspect-Based-Sentiment-Analysis/prova.py
# Out:
# Downloading: 100% 1.08k/1.08k [00:00<00:00, 1.11MB/s]
# Downloading: 100% 438M/438M [00:11<00:00, 38.0MB/s]
# 2020-12-27 21:16:37.608966: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-27 21:16:37.648096: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-27 21:16:37.648710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-12-27 21:16:37.648999: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python /content/Aspect-Based-Sentiment-Analysis/examples/train_classifier.py --domain restaurant --n_trials 1
# Out:
# [I 2020-12-27 21:21:12,845] Using an existing study with name 'classifier-restaurant' instead of creating a new one.
# 2020-12-27 21:21:13.754679: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-27 21:21:13.792701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-27 21:21:13.793320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-12-27 21:21:13.793593: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
#necessari per poter avviare la fase di test, i seguenti comandi!
#!python -m spacy download en
#import spacy
#spacy.load('en')
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 563 kB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047106 sha256=b4bebc4873cac087be35c4011765c6da5c7bfdff3284ec5ed3325e341c18fb83
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qw6n8t1v/wheels/10/6f/a6/ddd8204ceecdedddea923f8514e13afb0c1f0f556d2c9c3da0
# Successfully built en-core-web-sm
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/site-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !python /content/Aspect-Based-Sentiment-Analysis/tests/test_performance.py
# Out:
# 2020-12-27 21:20:09.270189: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-27 21:20:09.311812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-27 21:20:09.312402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-12-27 21:20:09.312655: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-27 21:20:09.314135: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# ...

# %%
#VEDIAMO DOMANI QUESTO
#!python /content/Aspect-Based-Sentiment-Analysis/tests/data/test_semeval.py
#!cp /content/Aspect-Based-Sentiment-Analysis/data/semeval/adapter.py /content/Aspect-Based-Sentiment-Analysis/tests/data
